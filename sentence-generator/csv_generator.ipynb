# %%
import csv

train_data = [
    {
        "prompt": "How are you?",
        "user_input": "How, you"
    },
    {
        "prompt": "He is a big and tall",
        "user_input": "He/she, big, tall"
    },
    {
        "prompt": "I not sleep tonight.",
        "user_input": "I/Me, Not, Sleep, Night"
    },
    {
        "prompt": "You don't like me?.",
        "user_input": "You, Not, Like, I/Me"
    },
    {
        "prompt": "Hello, it's a bright and sunny day.",
        "user_input": "hello, bright, sunny, day",
    },
    {
        "prompt": "I said hello to my neighbor as I passed by.",
        "user_input": "I/Me hello, neighbor, passed by",
    },
    {
        "prompt": "I want to thank you for your support during this difficult time.",
        "user_input": "I/Me, good/thank, deeds, support, difficult time",
    },
    {
        "prompt": "How are you?",
        "user_input": "How, you"
    },
    {
        "prompt": "I need your help to complete this task quickly.",
        "user_input": "I/Me, help, task, fast/quick",
    },
    {
        "prompt": "Can you help me find the solution to this problem?",
        "user_input": "Can you, help, me/I, find, solution, problem",
    },
    {
        "prompt": "Thanks for your help.",
        "user_input": "good/thank, you, help",
    },
    {
        "prompt": "How are you?",
        "user_input": "How, you"
    },
    {
        "prompt": "She always finishes her work quickly and comprehends complex topics with ease.",
        "user_input": "he/she, finish/complete, fast/quick, comprehend, complex topics",
    },
    {
        "prompt": "He always helps me understand complex topics quickly.",
        "user_input": "he/she, help, I/Me, understand/comprehend, quick/fast, complex topics",
    },
    {
        "prompt": "He always helps me understand topics quickly.",
        "user_input": "He/She, help, I/Me, understand, fast/quick, topics",
    },
    {
        "prompt": "She always helps me quickly.",
        "user_input": "he/she, please, help, me, fast/quick",
    },
    {"prompt": "Please help me.", "user_input": "help, Me/I"},
    {
        "prompt": "I'm really sorry for the mistake I made.",
        "user_input": "I/Me, sorry, mistake",
    },
    {
        "prompt": "She said she's sorry for the inconvenience and will fix it as soon as possible.",
        "user_input": " she/he, sorry, inconvenience, fix, soon",
    },
    {
        "prompt": "You're always welcome to join our team meetings.",
        "user_input": " you, welcome, join, team meetings",
    },
    {
        "prompt": "Everything is going to be ok, don't worry.",
        "user_input": "everything, be, ok, worry",
    },
    {
        "prompt": "What do you think about the new project proposal?",
        "user_input": "what, think, new project proposal",
    },
    {
        "prompt": "I love to eat delicious food in my favorite restaurant.",
        "user_input": "I/Me, love, eat/food, delicious, favorite restaurant",
    },
    {
        "prompt": "She's wondering what to eat for lunch today.",
        "user_input": "she/he, eat/food, wondering, lunch, today",
    },
    {
        "prompt": "She has a meeting at 2 PM, so she can't join us for lunch.",
        "user_input": "she/he, have/has/had, meeting, 2 PM, join",
    },
    {
        "prompt": "I had a great time at the concert last night.",
        "user_input": " I/Me, have/has/had, great time, concert, last night",
    },
    {
        "prompt": "I have a lot of work to do today, and I don't have much time.",
        "user_input": "I/Me, have/has/had, work, today, time",
    },
    {
        "prompt": "I need to complete this report by the end of the day.",
        "user_input": "I/Me, finish/complete, need, report, end of the day",
    },
    {
        "prompt": "He always finishes his work quickly and with great accuracy.",
        "user_input": "he/she, finish/complete, work, fast/quick, great accuracy",
    },
    {
        "prompt": "I understand the importance of completing the project on time.",
        "user_input": "I/Me, understand/comprehend, importance, completing, project, on time",
    },
    {
        "prompt": "She always comprehends complex topics quickly and with ease.",
        "user_input": "he/she, understand/comprehend, complex topics, fast/quick, with ease",
    },
    {
        "prompt": "I need to send a text message to confirm the meeting time.",
        "user_input": "I/Me, send text/message, need, confirm, meeting time",
    },
    {
        "prompt": "She's wondering if she should send a message to apologize.",
        "user_input": "he/she, send text/message, wondering, should, apologize",
    },
    {
        "prompt": "I like the same flavor of ice cream as you do.",
        "user_input": "I/Me, same/also, like, flavor, ice cream, you",
    },
    {
        "prompt": "She also plans to read it over the weekend.",
        "user_input": "he/she, same/also, plans, read, over the weekend",
    },
    {
        "prompt": "I need to find a fast solution to this problem.",
        "user_input": "I/Me, fast/quick, need, find, solution, problem",
    },
    {
        "prompt": "She always completes her tasks quickly",
        "user_input": "he/she, finish/complete, tasks, fast/quick",
    },
    {
        "prompt": "She prefers to shop at the same store ",
        "user_input": "he/she, store/shop, prefers, at, same/also",
    },
    {
        "prompt": "I need to visit the store to buy some groceries.",
        "user_input": "I/Me, store/shop, need, visit, buy, groceries",
    },
    {
        "prompt": "She needs to tell me the details of the meeting tomorrow.",
        "user_input": "he/she, tell, need, me, details, meeting, tomorrow",
    },
    {
        "prompt": "I love eating pizza with my friends.",
        "user_input": "I/Me, Love, eat/food, Pizza, Friends",
    },
    {
        "prompt": "The flowers are blooming in the garden.",
        "user_input": "Flowers, Blooming, Garden",
    },
    {
        "prompt": "The waves crash against the shore.",
        "user_input": "Waves, Crash, Shore",
    },
    {
        "prompt": "I enjoy playing guitar in my free time.",
        "user_input": "I/Me, Enjoy, Playing, Guitar, Free Time",
    },
    {
        "prompt": "The cat curled up by the fireplace.",
        "user_input": "I/Me, Cat, Curled, Fireplace",
    },
    {
        "prompt": "The chef prepared a delicious meal for us.",
        "user_input": "Chef, Prepared, Delicious, Meal, Us",
    },
    {
        "prompt": "The children are playing in the park.",
        "user_input": "Children, Playing, Park",
    },
    {
        "prompt": "I like to read books on a rainy day.",
        "user_input": "I/Me, Like, Read, Books, Rainy Day",
    },
    {
        "prompt": "The mountain peak was covered in snow.",
        "user_input": "Mountain, Peak, Covered, Snow",
    },
    {
        "prompt": "We had a great time at the beach yesterday.",
        "user_input": "We, have/has/had, Great Time, Beach, Yesterday",
    },
    {
        "prompt": "The coffee is strong and bitter.",
        "user_input": "Coffee, Strong, Bitter",
    },
    {
        "prompt": "The stars shine brightly in the night sky.",
        "user_input": "Stars, Shine, Bright, Night Sky",
    },
    {
        "prompt": "I watched a thrilling movie last night.",
        "user_input": "I/Me, Watched, Thrill, Movie, Last Night",
    },
    {"prompt": "The car sped down the highway.",
        "user_input": "Car, Sped, Highway"},
    {
        "prompt": "I enjoy a warm cup of tea in the morning.",
        "user_input": "I/Me, Enjoy, Warm Cup, Tea, Morning",
    },
    {
        "prompt": "The soccer team celebrated their victory.",
        "user_input": "Soccer Team, Celebrated, Victory",
    },
    {
        "prompt": "I danced to the rhythm of the music.",
        "user_input": "I/Me, Danced, Rhythm, Music",
    },
    {
        "prompt": "The rain tapped on the windowpane.",
        "user_input": "Rain, Tapped, Windowpane",
    },
    {
        "prompt": "I like to go hiking in the mountains.",
        "user_input": "I/Me, Like, Hiking, Mountains",
    },
    {
        "prompt": "The fire crackles in the fireplace.",
        "user_input": "Fire, Crackles, Fireplace",
    },
    {
        "prompt": "I find solace in the peaceful night.",
        "user_input": "I/Me, Find, Solace, Peaceful, Night",
    },
    {
        "prompt": "The airplane soars high in the sky.",
        "user_input": "Airplane, Soars, High, Sky",
    },
    {
        "prompt": "I cherish the moments spent with family.",
        "user_input": "I/Me, Cherish, Moments, Family",
    },
    {
        "prompt": "The river flows gently through the valley.",
        "user_input": "River, Flows, Gently, Valley",
    },
    {
        "prompt": "I admire the beauty of a blooming rose.",
        "user_input": "I/Me, Admire, Beauty, Blooming, Rose",
    },
    {
        "prompt": "The baby giggles and plays with toys.",
        "user_input": "Baby, Giggles, Plays, Toys",
    },
    {
        "prompt": "I love the taste of freshly baked bread.",
        "user_input": "I/Me, Love, Taste, Freshly Baked, Bread",
    },
    {
        "prompt": "The butterfly flutters in the garden.",
        "user_input": "Butterfly, Flutters, Garden",
    },
    {
        "prompt": "I enjoy a cup of hot cocoa in winter.",
        "user_input": "I/Me, Enjoy, Cup, Hot Cocoa, Winter",
    },
    {
        "prompt": "The clock ticks away the hours.",
        "user_input": "Clock, Ticks, Away, Hours",
    },
    {
        "prompt": "I savor a delicious cake.",
        "user_input": "I/Me, Savor, Delicious, Cake",
    },
    {
        "prompt": "The wind rustles the leaves in the forest.",
        "user_input": "Wind, Rustles, Leaves, Forest",
    },
    {
        "prompt": "I find peace in the quiet of the library.",
        "user_input": "I/Me, Find, Peace, Quiet, Library",
    },
    {
        "prompt": "The lion roars in the wilderness.",
        "user_input": "Lion, Roars, Wilderness",
    },
    {
        "prompt": "I love the feeling of sand between my toes.",
        "user_input": "I/Me, Love, Feeling, Sand, Between Toes",
    },
    {
        "prompt": "The car races down the winding road.",
        "user_input": "Car, Races, Down, Winding Road",
    },
    {
        "prompt": "I admire the elegance of a swan in the lake.",
        "user_input": "I/Me, Admire, Elegance, Swan, Lake",
    },
    {
        "prompt": "The storm rages on with thunder and lightning.",
        "user_input": "Storm, Rages, Thunder, Lightning",
    },
    {
        "prompt": "I enjoy a cold ice cream on a hot day.",
        "user_input": "I/Me, Enjoy, Cold, Ice Cream, Hot Day",
    },
    {
        "prompt": "The hiker reaches the summit of the mountain.",
        "user_input": "Hiker, Reaches, Summit, Mountain",
    },
    {
        "prompt": "I feel joy watching the colorful fireworks.",
        "user_input": "I/Me, Feel, Joy, Colorful, Fireworks",
    },
    {
        "prompt": "The boat sails on the calm waters of the lake.",
        "user_input": "Boat, Sails, Calm Waters, Lake",
    },
    {
        "prompt": "I like to explore new places on weekends.",
        "user_input": "I/Me, Like, Explore, New Places, Weekends",
    },
    {
        "prompt": "The elephant trumpets in the safari.",
        "user_input": "Elephant, Trumpets, Safari",
    },
    {
        "prompt": "I relax in a hammock under the palm trees.",
        "user_input": "I/Me, Relax, Hammock, Palm Trees",
    },
    {
        "prompt": "The computer processes data quickly.",
        "user_input": "Computer, Processes, Data, fast/quick",
    },
    {
        "prompt": "I find inspiration in the art of painting.",
        "user_input": "I/Me, Find, Inspiration, Art, Painting",
    },
    {
        "prompt": "The ocean waves crash on the sandy beach.",
        "user_input": "Ocean Waves, Crash, Sandy Beach",
    },
    {
        "prompt": "I admire the bravery of firefighters.",
        "user_input": "I/Me, Admire, Bravery, Firefighters",
    },
    {
        "prompt": "The scientist conducts experiments in the lab.",
        "user_input": "Scientist, Conducts, Experiments, Lab",
    },
    {
        "prompt": "I enjoy a cup of herbal tea in the evening.",
        "user_input": "I/Me, Enjoy, Cup, Herbal Tea, Evening",
    },
    {
        "prompt": "The violinist plays a soulful melody.",
        "user_input": "Violinist, Plays, Soulful, Melody",
    },
    {
        "prompt": "I love to watch the stars twinkle at night.",
        "user_input": "I/Me, Love, Watch, Stars, Twinkle, Night",
    },
    {
        "prompt": "The mountain climber reaches the peak.",
        "user_input": "Mountain Climber, Reaches, Peak",
    },
    {
        "prompt": "I relax with a good book by the fireplace.",
        "user_input": "I/Me, Relax, good/thank, book, Fireplace",
    },
    {
        "prompt": "The food at the restaurant was really good.",
        "keywords": "good/thank, Eat/Food, Restaurant"
    },
    {
        "prompt": "I had a good day at work.",
        "keywords": "I/Me, have/has/had, good/thank, Day, Work"
    },
    {
        "prompt": "The snow falls gently on a winter day.",
        "user_input": "Snow, Falls, Gently, Winter Day",
    },
    {
        "prompt": "I admire the agility of gymnasts.",
        "user_input": "I/Me, Admire, Agility, Gymnasts",
    },
    {
        "prompt": "The painter creates a masterpiece on canvas.",
        "user_input": "Painter, Creates, Masterpiece, Canvas",
    },
    {
        "prompt": "I enjoy a walk in the park on a sunny day.",
        "user_input": "I/Me, Enjoy, Walk, Park, Sunny Day",
    },
    {
        "prompt": "The astronaut floats in space.",
        "user_input": "Astronaut, Floats, Space",
    },
    {
        "prompt": "I find serenity in the sounds of nature.",
        "user_input": "I/Me, Find, Serenity, Sounds, Nature",
    },
    {
        "prompt": "The artist sculpts a beautiful sculpture.",
        "user_input": "Artist, Sculpts, Beautiful, Sculpture",
    },
    {
        "prompt": "I love the smell of fresh-baked bread.",
        "user_input": "I/Me, Love, Smell, Fresh-Baked, Bread",
    },
    {
        "prompt": "The storm clouds gather in the sky.",
        "user_input": "Storm Clouds, Gather, Sky",
    },
    {
        "prompt": "I feel excitement at an amusement park.",
        "user_input": "I/Me, Feel, Excitement, Amusement Park",
    },
    {
        "prompt": "The dancer twirls gracefully on the stage.",
        "user_input": "Dancer, Twirls, Gracefully, Stage",
    },
    {
        "prompt": "I enjoy a picnic in the park with friends.",
        "user_input": "I/Me, Enjoy, Picnic, Park, Friends",
    },
    {
        "prompt": "I find beauty in the colors of a rainbow.",
        "user_input": "I/Me, Find, Beauty, Colors, Rainbow",
    },
    {
        "prompt": "The boat sails on the open sea.",
        "user_input": "Boat, Sails, Open Sea",
    },
    {
        "prompt": "I love the taste of chocolate ice cream.",
        "user_input": "I/Me, Love, Taste, Chocolate Ice Cream",
    },
    {
        "prompt": "The explorer treks through the jungle.",
        "user_input": "Explorer, Treks, Jungle",
    },
    {
        "prompt": "I find inspiration in the art of dance.",
        "user_input": "I/Me, Find, Inspiration, Art, Dance",
    },
    {
        "prompt": "The runner races towards the finish line.",
        "user_input": "Runner, Races, finish/complete",
    },
    {
        "prompt": "I enjoy a stroll in the countryside.",
        "user_input": "I/Me, Enjoy, Stroll, Countryside",
    },
    {
        "prompt": "The dog barks loudly in the yard.",
        "user_input": "Dog, Barks, Loudly, Yard",
    },
    {
        "prompt": "I feel calm by the riverside.",
        "user_input": "I/Me, Feel, Calm, Riverside",
    },
    {
        "prompt": "The guitarist strums a catchy tune.",
        "user_input": "Guitarist, Strums, Catchy, Tune",
    },
    {
        "prompt": "I love to swim in the crystal-clear water.",
        "user_input": "I/Me, Love, Swim, Crystal-Clear, Water",
    },
    {
        "prompt": "The sunsets are beautiful by the beach.",
        "user_input": "Sunsets, Beautiful, Beach",
    },
    {
        "prompt": "I enjoy a cup of herbal tea in the evening.",
        "user_input": "I/Me, Enjoy, Cup, Herbal Tea, Evening",
    },
    {
        "prompt": "The architect designs innovative buildings.",
        "user_input": "Architect, Designs, Innovative, Buildings",
    },
    {
        "prompt": "I find excitement in the city's hustle and bustle.",
        "user_input": "I/Me, Find, Excitement, City's Hustle And Bustle",
    },
    {
        "prompt": "The construction worker lays bricks for a new wall.",
        "user_input": "Construction Worker, Lays Bricks, New Wall",
    },
    {
        "prompt": "The runner sprints towards the finish line.",
        "user_input": "Runner, Sprints, finish/complete",
    },
    {
        "prompt": "I find inspiration in the art of sculpture.",
        "user_input": "I/Me, Find, Inspiration, Art, Sculpture",
    },
    {
        "prompt": "The sunflowers sway in the breeze.",
        "user_input": "Sunflowers, Sway, Breeze",
    },
    {
        "prompt": "I relax by the fireplace on a cold winter night.",
        "user_input": "I/Me, Relax, Fireplace, Cold Winter Night",
    },
    {
        "prompt": "The scientist conducts experiments in the lab.",
        "user_input": "Scientist, Conducts, Experiments, Lab",
    },
    {
        "prompt": "I enjoy a cup of hot cocoa by the fireplace.",
        "user_input": "I/Me, Enjoy, Cup, Hot Cocoa, Fireplace",
    },
    {
        "prompt": "The chef prepares a gourmet meal for guests.",
        "user_input": "Chef, Prepares, Gourmet Meal, Guests",
    },
    {
        "prompt": "I find joy in the melody of a songbird.",
        "user_input": "I/Me, Find, Joy, Melody, Songbird",
    },
    {
        "prompt": "The wind howls through the night.",
        "user_input": "Wind, Howls, Night"
    },
    {
        "prompt": "I need you to bring me some food.",
        "user_input": "I/Me, take/bring me, Eat/Food",
    },
    {
        "prompt": "Can he finish the race so quickly?",
        "user_input": "he/she, finish/complete, fast/quick",
    },
    {
        "prompt": "She also understands the importance of the task.",
        "user_input": "he/she, understand/comprehend, same/also",
    },
    {
        "prompt": "You should take a break from work.",
        "user_input": "You, take/bring me, break, work",
    },
    {"prompt": "Do you know where he is going?",
        "user_input": "he/she, know, going"},
    {
        "prompt": "I can finish this puzzle in no time.",
        "user_input": "I/Me, finish/complete, fast/quick",
    },
    {"prompt": "She is very quick to respond.",
        "user_input": "he/she, fast/quick, respond"},
    {
        "prompt": "You and I also enjoy the same music.",
        "user_input": "You, I/Me, same/also, enjoy, music",
    },
    {
        "prompt": "Can she comprehend the instructions clearly?",
        "user_input": "he/she, understand/comprehend, clear",
    },
    {"prompt": "You should bring me some tea.",
        "user_input": "You, take/bring me, tea"},
    {
        "prompt": "Do you understand how he completed the task so fast?",
        "user_input": "he/she, understand/comprehend, I/Me, finish/complete, fast/quick",
    },
    {
        "prompt": "He and I can work on the same project.",
        "user_input": "he/she, same/also, I, can, work, project",
    },
    {
        "prompt": "I need you to bring me to the airport.",
        "user_input": "I/Me, You, take/bring me, airport",
    },
    {
        "prompt": "Can he comprehend the complexity of the problem?",
        "user_input": "he/she, understand/comprehend, complexity",
    },
    {"prompt": "You should bring me some water.",
        "user_input": "You, take/bring me, water"},
    {
        "prompt": "Do you understand why he is so quick?",
        "user_input": "he/she, understand/comprehend, fast/quick",
    },
    {
        "prompt": "He can finish the race faster than anyone.",
        "user_input": "he/she, finish/complete, fast/quick, anyone",
    },
    {
        "prompt": "She also understands the situation well.",
        "user_input": "he/she, understand/comprehend, same/also, well",
    },
    {
        "prompt": "I need you to bring me dinner tonight.",
        "user_input": "I/Me, You, take/bring me, dinner, tonight",
    },
    {
        "prompt": "Can he comprehend the meaning of the poem?",
        "user_input": "he/she, understand/comprehend, meaning, poem",
    },
    {
        "prompt": "She is also very quick to respond.",
        "user_input": "he/she, same/also, fast/quick, respond",
    },
    {
        "prompt": "You and I both enjoy the same food.",
        "user_input": "You, I, same/also, enjoy, Eat/Food",
    },
    {
        "prompt": "I need you to take me to the station.",
        "user_input": "I/Me, You, take/bring me, station",
    },
    {
        "prompt": "Do you understand how he finished the project so fast?",
        "user_input": "he/she, understand/comprehend, I/Me, finish/complete, project, fast/quick",
    },
    {
        "prompt": "You should bring me lunch today.",
        "user_input": "You, take/bring me, lunch, today",
    },
    {
        "prompt": "Can he comprehend the complexity of the problem?",
        "user_input": "he/she, understand/comprehend, complexity",
    },
    {
        "prompt": "She also understands the situation well.",
        "user_input": "he/she, understand/comprehend, same/also, well",
    },
    {
        "prompt": "I need you to take me to the airport.",
        "user_input": "I/Me, You, take/bring me, airport",
    },
    {
        "prompt": "Do you understand why he is so quick?",
        "user_input": "he/she, understand/comprehend, fast/quick",
    },
    {
        "prompt": "He can finish the race faster than anyone.",
        "user_input": "he/she, finish/complete, fast/quick, anyone",
    },
    {
        "prompt": "She and I both enjoy the same music.",
        "user_input": "he/she, same/also, I, enjoy, music",
    },
    {
        "prompt": "I need you to bring me breakfast.",
        "user_input": "I/Me, You, take/bring me, breakfast",
    },
    {
        "prompt": "Can he comprehend the meaning of the poem?",
        "user_input": "he/she, understand/comprehend, meaning, poem",
    },
    {
        "prompt": "She is also very quick to respond.",
        "user_input": "he/she, fast/quick, same/also",
    },
    {
        "prompt": "You and I both enjoy the same food.",
        "user_input": "You, I, same/also, enjoy, Eat/Food",
    },
    {
        "prompt": "I need you to take me to the station.",
        "user_input": "I/Me, You, take/bring me, station",
    },
    {
        "prompt": "Do you understand how he finished the project so fast?",
        "user_input": "he/she, understand/comprehend, I/Me, finish/complete, fast/quick",
    },
    {
        "prompt": "You should bring me dinner tonight.",
        "user_input": "You, take/bring me, dinner, tonight",
    },
    {
        "prompt": "Can he comprehend the complexity of the problem?",
        "user_input": "he/she, understand/comprehend, complexity",
    },
    {
        "prompt": "She also understands the situation well.",
        "user_input": "he/she, understand/comprehend, same/also, well",
    },
    {
        "prompt": "I need you to bring me to the airport.",
        "user_input": "I/Me, You, take/bring me, airport",
    },
    {
        "prompt": "Do you understand why he is so quick?",
        "user_input": "he/she, understand/comprehend, fast/quick",
    },
    {
        "prompt": "He can finish the race faster than anyone.",
        "user_input": "he/she, finish/complete, fast/quick, anyone",
    },
    {
        "prompt": "She and I both enjoy the same music.",
        "user_input": "he/she, same/also, I, enjoy, music",
    },
    {
        "prompt": "I need you to bring me breakfast.",
        "user_input": "I/Me, You, take/bring me, breakfast",
    },
    {
        "prompt": "Can he comprehend the meaning of the poem?",
        "user_input": "he/she, understand/comprehend, meaning, poem",
    },
    {
        "prompt": "You and I both enjoy the same food.",
        "user_input": "You, I, same/also, enjoy, Eat/Food",
    },
    {
        "prompt": "I need you to take me to the station.",
        "user_input": "I/Me, You, take/bring me, station",
    },
    {
        "prompt": "Do you understand how he finished the project so fast?",
        "user_input": "he/she, understand/comprehend, I/Me, finish/complete, fast/quick",
    },
    {
        "prompt": "The car moves fast on the highway.",
        "user_input": "Car, Moves, fast/quick, Highway",
    },
    {
        "prompt": "I understand the importance of education.",
        "user_input": "I/Me, understand/comprehend, Importance, Education",
    },
    {
        "prompt": "The chef prepares food for the guests.",
        "user_input": "Chef, Prepares, Eat/Food, Guests",
    },
    {
        "prompt": "He finishes his work quickly and efficiently.",
        "user_input": "He/She, Finishes, Work, fast/quick, Efficient",
    },
    {
        "prompt": "The students comprehend complex topics in class.",
        "user_input": "Students, understand/comprehend, Complex Topics, Class",
    },
    {
        "prompt": "The movie is the same as the book it's based on.",
        "user_input": "Movie, Same, Book, Based On",
    },
    {
        "prompt": "She takes a break to have lunch with me.",
        "user_input": "He/She, take/bring me, Break, Lunch, I/Me",
    },
    {
        "prompt": "The cat eats its food slowly and carefully.",
        "user_input": "Cat, Eat/Food, Slowly, Carefully",
    },
    {
        "prompt": "I finish my tasks before the deadline.",
        "user_input": "I/Me, finish/complete, Tasks, Before Deadline",
    },
    {"prompt": "The dog runs fast in the park.",
        "user_input": "Dog, Runs, fast/quick, Park"},
    {
        "prompt": "She understands the complexity of the situation.",
        "user_input": "He/She, understand/comprehend, Complexity, Situation",
    },
    {
        "prompt": "The team completes the project on time.",
        "user_input": "Team, finish/complete, Project, On Time",
    },
    {
        "prompt": "I take my dog for a walk every morning.",
        "user_input": "I/Me, take/bring me, Dog, Walk, Every Morning",
    },
    {
        "prompt": "The flowers in the garden look beautiful.",
        "user_input": "Flowers, Look, Beautiful, Garden",
    },
    {
        "prompt": "He also enjoys playing soccer.",
        "user_input": "He/She, same/also, Enjoys, Playing, Soccer",
    },
    {
        "prompt": "I find solace in the quiet of the forest.",
        "user_input": "I/Me, Find, Solace, Quiet, Forest",
    },
    {
        "prompt": "The bird sings a sweet melody.",
        "user_input": "Bird, Sings, Sweet Melody",
    },
    {
        "prompt": "She finishes her meal quickly.",
        "user_input": "He/She, Finishes, Meal, fast/quick",
    },
    {
        "prompt": "The athlete runs fast in the race.",
        "user_input": "Athlete, Runs, fast/quick, Race",
    },
    {
        "prompt": "I take a moment to enjoy the sunset.",
        "user_input": "I/Me, take/bring me, Moment, Enjoy, Sunset",
    },
    {
        "prompt": "The car moves quickly on the highway.",
        "user_input": "Car, Move, fast/quick, Highway",
    },
    {
        "prompt": "I comprehend the instructions clearly.",
        "user_input": "I/Me, understand/comprehend, Instructions, Clearly",
    },
    {
        "prompt": "The child finishes their homework early.",
        "user_input": "Child, Finishes, Homework, Early",
    },
    {
        "prompt": "He also loves playing video games.",
        "user_input": "He/She, same/also, Loves, Playing, Video Games",
    },
    {
        "prompt": "I find peace in the beauty of nature.",
        "user_input": "I/Me, Find, Peace, Beauty, Nature",
    },
    {
        "prompt": "The artist creates beautiful paintings.",
        "user_input": "Artist, Creates, Beautiful Paintings",
    },
    {
        "prompt": "She understands the intricacies of the technology.",
        "user_input": "He/She, understand/comprehend, Intricacies, Technology",
    },
    {
        "prompt": "The musicians play the same song again.",
        "user_input": "Musicians, Play, Same Song, Again",
    },
    {
        "prompt": "I enjoy eating pizza with my friends.",
        "user_input": "I/Me, Enjoy, Eating, Pizza, Friends",
    },
    {
        "prompt": "The sun shines brightly in the sky.",
        "user_input": "Sun, Shines, Brightly, Sky",
    },
    {
        "prompt": "He takes a walk in the park every evening.",
        "user_input": "He/She, take/bring me, Walk, Park, Every Evening",
    },
    {
        "prompt": "I find solace in reading a good book.",
        "user_input": "I/Me, Find, Solace, Reading, good/thank, Book",
    },
    {
        "prompt": "The car races down the winding road.",
        "user_input": "Car, Races, Down, Winding Road",
    },
    {
        "prompt": "She enjoys the taste of chocolate ice cream.",
        "user_input": "He/She, Enjoys, Taste, Chocolate Ice Cream",
    },
    {
        "prompt": "I admire the beauty of a blooming rose.",
        "user_input": "I/Me, Admire, Beauty, Blooming Rose",
    },
    {
        "prompt": "The mountain climber reaches the peak.",
        "user_input": "Mountain Climber, Reaches, Peak",
    },
    {
        "prompt": "He finds excitement in solving puzzles.",
        "user_input": "He/She, Finds, Excitement, Solving Puzzles",
    },
    {
        "prompt": "I enjoy a picnic in the park with friends.",
        "user_input": "I/Me, Enjoy, Picnic, Park, Friends",
    },
    {
        "prompt": "The ocean waves crash on the sandy beach.",
        "user_input": "Ocean Waves, Crash, Sandy Beach",
    },
    {
        "prompt": "She takes a moment to relax in the garden.",
        "user_input": "He/She, take/bring me, Moment, Relax, Garden",
    },
    {
        "prompt": "I find joy in the laughter of children playing.",
        "user_input": "I/Me, Find, Joy, Laughter, Children Playing",
    },
    {
        "prompt": "The dog barks loudly in the yard.",
        "user_input": "Dog, Barks, Loudly, Yard",
    },
    {
        "prompt": "He finishes his work before lunchtime.",
        "user_input": "He/She, Finishes, Work, Before Lunchtime",
    },
    {
        "prompt": "I also appreciate a good cup of coffee.",
        "user_input": "I/Me, same/also, Appreciate, Good Cup, Coffee",
    },
    {
        "prompt": "The river flows gently through the valley.",
        "user_input": "River, Flows, Gently, Valley",
    },
    {
        "prompt": "She understands the art of storytelling.",
        "user_input": "He/She, understand/comprehend, Art, Storytelling",
    },
    {
        "prompt": "The snow covers the landscape in white.",
        "user_input": "Snow, Covers, Landscape, White",
    },
    {
        "prompt": "I find tranquility in the shade of a tree.",
        "user_input": "I/Me, Find, Tranquility, Shade, Tree",
    },
    {
        "prompt": "The painter adds vibrant colors to the canvas.",
        "user_input": "Painter, Adds, Vibrant Colors, Canvas",
    },
    {
        "prompt": "She also loves to swim in the clear water.",
        "user_input": "He/She, same/also, Loves, Swim, Clear Water",
    },
]

# Create and write the data to a CSV file
with open('training.csv', 'w', newline='') as csvfile:
    fieldnames = ["prompt", "user_input"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for entry in train_data:
        writer.writerow(entry)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\FYP\Program\sign-language-recognition\sentence-generator\csv_generator.ipynb Cell 1 line 9
#     <a href='vscode-notebook-cell:/e%3A/FYP/Program/sign-language-recognition/sentence-generator/csv_generator.ipynb#W0sZmlsZQ%3D%3D?line=927'>928</a> writer.writeheader()
#     <a href='vscode-notebook-cell:/e%3A/FYP/Program/sign-language-recognition/sentence-generator/csv_generator.ipynb#W0sZmlsZQ%3D%3D?line=928'>929</a> for entry in train_data:
# --> <a href='vscode-notebook-cell:/e%3A/FYP/Program/sign-language-recognition/sentence-generator/csv_generator.ipynb#W0sZmlsZQ%3D%3D?line=929'>930</a>     writer.writerow(entry)
#
# File c:\Users\Eng Lip\AppData\Local\Programs\Python\Python39\lib\csv.py:154, in DictWriter.writerow(self, rowdict)
#     153 def writerow(self, rowdict):
# ...

# %%
val_data = [
       {
        "prompt": "The movie director calls 'Action!'",
        "user_input": "Movie Director, Calls, Action"
    },
    {
        "prompt": "I love to bake fresh cookies in the oven.",
        "user_input": "I/Me, Love, Bake, Fresh Cookies, Oven"
    },
    {
        "prompt": "The fisherman casts his line into the river.",
        "user_input": "Fisherman, Casts Line, River"
    },
    {
        "prompt": "I enjoy a cup of green tea in the morning.",
        "user_input": "I/Me, Enjoy, Cup, Green Tea, Morning"
    },
    {
        "prompt": "The astronaut floats in the zero gravity of space.",
        "user_input": "Astronaut, Floats, Zero Gravity, Space"
    },
    {
        "prompt": "I find beauty in the colors of a sunset.",
        "user_input": "I/Me, Find, Beauty, Colors, Sunset"
    },
    {
        "prompt": "The teacher imparts knowledge to students.",
        "user_input": "Teacher, Imparts Knowledge, Students"
    },
    {
        "prompt": "I relax by the lakeshore on a sunny day.",
        "user_input": "I/Me, Relax, Lakeshore, Sunny Day"
    },
    {
        "prompt": "The birds chirp in the early morning.",
        "user_input": "Birds, Chirp, Early Morning"
    },
    {
        "prompt": "I find serenity in the mountains' grandeur.",
        "user_input": "I/Me, Find, Serenity, Mountains' Grandeur"
    },
    {
        "prompt": "The painter adds brush strokes to the canvas.",
        "user_input": "Painter, Adds, Brush Strokes, Canvas"
    },
    {
        "prompt": "I love to dance to the rhythm of music.",
        "user_input": "I/Me, Love, Dance, Rhythm, Music"
    },
    {
        "prompt": "The cyclist races in the Tour de France.",
        "user_input": "Cyclist, Races, Tour de France"
    },
    {
        "prompt": "I enjoy the scent of blooming flowers in spring.",
        "user_input": "I/Me, Enjoy, Scent, Blooming Flowers, Spring"
    },
    {
        "prompt": "The truck rumbles down the highway.",
        "user_input": "Truck, Rumbles, Highway"
    },
    {
        "prompt": "I love to watch the snowfall on a winter morning.",
        "user_input": "I/Me, Love, Watch, Snowfall, Winter Morning"
    },
    {
        "prompt": "The dolphins swim gracefully in the ocean.",
        "user_input": "Dolphins, Swim, Gracefully, Ocean"
    },
    {
        "prompt": "I admire the determination of marathon runners.",
        "user_input": "I/Me, Admire, Determination, Marathon Runners"
    },
    {
        "prompt": "The photographer captures breathtaking landscapes.",
        "user_input": "Photographer, Captures, Breathtaking Landscapes"
    },
    {
        "prompt": "I find solace in the serenity of a mountain lake.",
        "user_input": "I/Me, Find, Solace, Serenity, Mountain Lake"
    },
    {
        "prompt": "The skydiver leaps from the airplane with excitement.",
        "user_input": "Skydiver, Leaps, From Airplane, Excitement"
    },
    {
        "prompt": "I love the taste of fresh strawberries in summer.",
        "user_input": "I/Me, Love, Taste, Fresh Strawberries, Summer"
    },
    {
        "prompt": "The bee buzzes around the garden flowers.",
        "user_input": "Bee, Buzzes, Around, Garden Flowers"
    },
    {
        "prompt": "I enjoy a hike through the forest on weekends.",
        "user_input": "I/Me, Enjoy, Hike, Through Forest, Weekends"
    },
    {
        "prompt": "The chef prepares a mouthwatering five-course meal.",
        "user_input": "Chef, Prepares, Mouthwatering, Five-Course Meal"
    },
    {
        "prompt": "I find joy in the laughter of children playing.",
        "user_input": "I/Me, Find, Joy, Laughter, Children Playing"
    },
    {
        "prompt": "The spaceship journeys to distant galaxies.",
        "user_input": "Spaceship, Journeys, Distant Galaxies"
    },
    {
        "prompt": "I relax on a hammock under the coconut palms.",
        "user_input": "I/Me, Relax, Hammock, Coconut Palms"
    },
    {
        "prompt": "The firework display lights up the night sky.",
        "user_input": "Firework Display, Lights Up, Night Sky"
    },
    {
        "prompt": "I love the aroma of a freshly baked apple pie.",
        "user_input": "I/Me, Love, Aroma, Freshly Baked, Apple Pie"
    },
    {
        "prompt": "The elephant parades majestically through the jungle.",
        "user_input": "Elephant, Parades, Majestically, Jungle"
    },
    {
        "prompt": "I find inspiration in the colors of a vibrant sunset.",
        "user_input": "I/Me, Find, Inspiration, Colors, Vibrant Sunset"
    },
    {
        "prompt": "The scuba diver explores the coral reefs beneath the sea.",
        "user_input": "Scuba Diver, Explores, Coral Reefs, Beneath Sea"
    },
    {
        "prompt": "I enjoy a picnic by the tranquil lakeside.",
        "user_input": "I/Me, Enjoy, Picnic, Tranquil Lakeside"
    },
    {
        "prompt": "The parrot chatters in the tropical rainforest.",
        "user_input": "Parrot, Chatters, Tropical Rainforest"
    },
    {
        "prompt": "I love to paint with watercolors on a sunny day.",
        "user_input": "I/Me, Love, Paint, Watercolors, Sunny Day"
    },
    {
        "prompt": "The construction crew builds a skyscraper in the city.",
        "user_input": "Construction Crew, Builds, Skyscraper, City"
    },
    {
        "prompt": "I find serenity in the soft rustling of leaves.",
        "user_input": "I/Me, Find, Serenity, Soft Rustling, Leaves"
    },
    {
        "prompt": "The astronaut floats in the vastness of space.",
        "user_input": "Astronaut, Floats, Vastness, Space"
    },
    {
        "prompt": "I enjoy a cup of green tea in the afternoon.",
        "user_input": "I/Me, Enjoy, Cup, Green Tea, Afternoon"
    },
    {
        "prompt": "The sculptor carves an intricate masterpiece.",
        "user_input": "Sculptor, Carves, Intricate, Masterpiece"
    },
    {
        "prompt": "I love the sound of crashing waves at the beach.",
        "user_input": "I/Me, Love, Sound Of, Crashing Waves, Beach"
    },
    {
        "prompt": "The pilot navigates the plane through turbulent skies.",
        "user_input": "Pilot, Navigates, Plane, Turbulent Skies"
    },
    {
        "prompt": "I find joy in the hustle and bustle of the city.",
        "user_input": "I/Me, Find, Joy, Hustle And Bustle, City"
    },
    {
        "prompt": "The turtle crawls slowly on the sandy shore.",
        "user_input": "Turtle, Crawls, Slowly, Sandy Shore"
    },
    {
        "prompt": "I relax in a hammock under the palm trees.",
        "user_input": "I/Me, Relax, Hammock, Palm Trees"
    },
    {
        "prompt": "The computer processes data with lightning speed.",
        "user_input": "Computer, Processes Data, Lightning Speed"
    }
]

with open('validation.csv', 'w', newline='') as csvfile:
    fieldnames = ["prompt", "user_input"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for entry in val_data:
        writer.writerow(entry)
