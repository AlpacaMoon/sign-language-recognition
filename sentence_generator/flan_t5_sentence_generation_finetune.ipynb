# %% [markdown]
# # Fine-tune FLAN-T5 for chat & dialogue summarization
#
# In this blog, you will learn how to fine-tune [google/flan-t5-xl](https://huggingface.co/google/flan-t5-xl) for chat & dialogue summarization using Hugging Face Transformers. If you already know T5, FLAN-T5 is just better at everything. For the same number of parameters, these models have been fine-tuned on more than 1000 additional tasks covering also more languages.
#
# In this example we will use the [samsum](https://huggingface.co/datasets/samsum) dataset a collection of about 16k messenger-like conversations with summaries. Conversations were created and written down by linguists fluent in English.
#
# You will learn how to:
#
# 1. [Setup Development Environment](#1-setup-development-environment)
# 2. [Load and prepare samsum dataset](#2-load-and-prepare-samsum-dataset)
# 3. [Fine-tune and evaluate FLAN-T5](#3-fine-tune-and-evaluate-flan-t5)
# 4. [Run Inference and summarize ChatGPT dialogues](#4-run-inference-and-summarize-chatgpt-dialogues)
#
# Before we can start, make sure you have a [Hugging Face Account](https://huggingface.co/join) to save artifacts and experiments.
#
# ## Quick intro: FLAN-T5, just a better T5
#
# FLAN-T5 released with the [Scaling Instruction-Finetuned Language Models](https://arxiv.org/pdf/2210.11416.pdf) paper is an enhanced version of T5 that has been finetuned in a mixture of tasks. The paper explores instruction finetuning with a particular focus on (1) scaling the number of tasks, (2) scaling the model size, and (3) finetuning on chain-of-thought data. The paper discovers that overall instruction finetuning is a general method for improving the performance and usability of pretrained language models.
#
# ![flan-t5](https://github.com/philschmid/deep-learning-pytorch-huggingface/blob/main/assets/flan-t5.png?raw=1)
#
# * Paper: https://arxiv.org/abs/2210.11416
# * Official repo: https://github.com/google-research/t5x
#
# ---
#
# Now we know what FLAN-T5 is, let's get started. 🚀
#
# _Note: This tutorial was created and run on a g4dn.xlarge AWS EC2 Instance including a NVIDIA T4._

# %% [markdown]
# ## 1. Setup Development Environment
#
# Our first step is to install the Hugging Face Libraries, including transformers and datasets. Running the following cell will install all the required packages.

# %%
# python
! pip install -U accelerate
! pip install -U transformers
! pip install pytesseract pandas transformers datasets evaluate rouge-score nltk tensorboard py7zr --upgrade
# Out:
# Collecting accelerate
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0.1-cp39-cp39-win_amd64.whl (152 kB)
# Requirement already satisfied, skipping upgrade: psutil in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from accelerate) (5.9.6)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from accelerate) (23.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from accelerate) (1.26.2)
# Collecting torch>=1.10.0
#   Downloading torch-2.1.1-cp39-cp39-win_amd64.whl (192.2 MB)
# Collecting tqdm>=4.42.1
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
# Requirement already satisfied, skipping upgrade: requests in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4.3 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from huggingface-hub->accelerate) (4.8.0)
# Collecting filelock
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied, skipping upgrade: colorama; platform_system == "Windows" in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->huggingface-hub->accelerate) (2.1.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=2.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: pyyaml, tqdm, filelock, fsspec, huggingface-hub, jinja2, mpmath, sympy, networkx, torch, accelerate
# Successfully installed accelerate-0.24.1 filelock-3.13.1 fsspec-2023.10.0 huggingface-hub-0.19.4 jinja2-3.1.2 mpmath-1.3.0 networkx-3.2.1 pyyaml-6.0.1 sympy-1.12 torch-2.1.1 tqdm-4.66.1
# Collecting transformers
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
#      ---------------------------------------- 0.0/123.5 kB ? eta -:--:--
#      -------------------------------------- 123.5/123.5 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2023.10.3-cp39-cp39-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB ? eta 0:00:00
# Requirement already satisfied: requests in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.0-cp39-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.1-cp39-none-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.8.0)
# Requirement already satisfied: colorama in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2023.11.17)
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/7.9 MB 9.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/7.9 MB 9.7 MB/s eta 0:00:01
#    ------ --------------------------------- 1.2/7.9 MB 9.7 MB/s eta 0:00:01
#    ------- -------------------------------- 1.4/7.9 MB 8.3 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/7.9 MB 7.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.8/7.9 MB 6.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.9 MB 6.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/7.9 MB 6.1 MB/s eta 0:00:01
#    ------------ --------------------------- 2.4/7.9 MB 5.7 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/7.9 MB 5.5 MB/s eta 0:00:01
#    ------------- -------------------------- 2.8/7.9 MB 5.2 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/7.9 MB 5.2 MB/s eta 0:00:01
#    -------------- ------------------------- 3.0/7.9 MB 5.1 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/7.9 MB 4.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.3/7.9 MB 4.7 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/7.9 MB 4.8 MB/s eta 0:00:01
#    -------------------- ------------------- 4.1/7.9 MB 5.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.3/7.9 MB 5.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.8/7.9 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 5.1/7.9 MB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.6/7.9 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/7.9 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.9 MB 6.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.9 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  7.9/7.9 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 6.7 MB/s eta 0:00:00
# Downloading regex-2023.10.3-cp39-cp39-win_amd64.whl (269 kB)
#    ---------------------------------------- 0.0/269.6 kB ? eta -:--:--
#    --------------------------------------- 269.6/269.6 kB 17.3 MB/s eta 0:00:00
# Downloading safetensors-0.4.1-cp39-none-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/277.8 kB ? eta -:--:--
#    ---------------------------------------- 277.8/277.8 kB 8.6 MB/s eta 0:00:00
# Downloading tokenizers-0.15.0-cp39-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.2 MB 30.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 15.6 MB/s eta 0:00:00
# Installing collected packages: safetensors, regex, tokenizers, transformers
# Successfully installed regex-2023.10.3 safetensors-0.4.1 tokenizers-0.15.0 transformers-4.35.2
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting pandas
#   Downloading pandas-2.1.3-cp39-cp39-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: transformers in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (4.35.2)
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------- ----------------------------- 0.4/1.5 MB 8.1 MB/s eta 0:00:01
#      --------------------- ------------------ 0.8/1.5 MB 8.7 MB/s eta 0:00:01
#      ------------------------------- -------- 1.2/1.5 MB 7.6 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (2.15.1)
# Collecting py7zr
#   Downloading py7zr-0.20.8-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from pytesseract) (10.1.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (0.19.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from transformers) (4.66.1)
# Collecting pyarrow>=8.0.0 (from datasets)
#   Downloading pyarrow-14.0.1-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp39-cp39-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py39-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.9.1-cp39-cp39-win_amd64.whl.metadata (7.6 kB)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: absl-py in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from rouge-score) (2.0.0)
# Requirement already satisfied: six>=1.14.0 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from rouge-score) (1.16.0)
# Collecting click (from nltk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (49.2.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from tensorboard) (3.0.1)
# Collecting texttable (from py7zr)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr)
#   Downloading pycryptodomex-3.19.0-cp35-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting pyzstd>=0.15.9 (from py7zr)
#   Downloading pyzstd-0.15.9-cp39-cp39-win_amd64.whl.metadata (7.6 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr)
#   Downloading pyppmd-1.1.0-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr)
#   Downloading pybcj-1.0.2-cp39-cp39-win_amd64.whl.metadata (4.1 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr)
#   Downloading inflate64-1.0.0-cp39-cp39-win_amd64.whl.metadata (4.1 kB)
# Collecting brotli>=1.1.0 (from py7zr)
#   Downloading Brotli-1.1.0-cp39-cp39-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: psutil in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from py7zr) (5.9.6)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.3-cp39-cp39-win_amd64.whl.metadata (29 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.4.0-cp39-cp39-win_amd64.whl.metadata (5.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.8.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\zhilin\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\zhilin\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)
# Downloading pandas-2.1.3-cp39-cp39-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.7/10.8 MB 14.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.4/10.8 MB 17.5 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/10.8 MB 17.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/10.8 MB 16.4 MB/s eta 0:00:01
#    -------------- ------------------------- 4.0/10.8 MB 17.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.8/10.8 MB 16.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.8 MB 16.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.8 MB 17.4 MB/s eta 0:00:01
#    -------------------------- ------------- 7.0/10.8 MB 17.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.0/10.8 MB 17.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.8/10.8 MB 17.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.8 MB 17.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.8 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 16.8 MB/s eta 0:00:00
# Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#    ---------------------------------------- 0.0/521.2 kB ? eta -:--:--
#    --------------------------------------- 521.2/521.2 kB 16.5 MB/s eta 0:00:00
# Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.1 kB ? eta -:--:--
#    ---------------------------------------- 84.1/84.1 kB ? eta 0:00:00
# Downloading py7zr-0.20.8-py3-none-any.whl (67 kB)
#    ---------------------------------------- 0.0/67.0 kB ? eta -:--:--
#    ---------------------------------------- 67.0/67.0 kB ? eta 0:00:00
# Downloading Brotli-1.1.0-cp39-cp39-win_amd64.whl (357 kB)
#    ---------------------------------------- 0.0/357.3 kB ? eta -:--:--
#    --------------------------------------- 357.3/357.3 kB 23.1 MB/s eta 0:00:00
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ---------------------------------------- 0.0/115.3 kB ? eta -:--:--
#    ---------------------------------------- 115.3/115.3 kB ? eta 0:00:00
# Downloading aiohttp-3.9.1-cp39-cp39-win_amd64.whl (365 kB)
#    ---------------------------------------- 0.0/365.5 kB ? eta -:--:--
#    ---------------------------------------- 365.5/365.5 kB ? eta 0:00:00
# Downloading inflate64-1.0.0-cp39-cp39-win_amd64.whl (35 kB)
# Downloading pyarrow-14.0.1-cp39-cp39-win_amd64.whl (24.6 MB)
#    ---------------------------------------- 0.0/24.6 MB ? eta -:--:--
#    - -------------------------------------- 1.0/24.6 MB 20.7 MB/s eta 0:00:02
#    --- ------------------------------------ 1.9/24.6 MB 17.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 3.0/24.6 MB 19.4 MB/s eta 0:00:02
#    ------ --------------------------------- 3.8/24.6 MB 20.3 MB/s eta 0:00:02
#    -------- ------------------------------- 5.2/24.6 MB 20.6 MB/s eta 0:00:01
#    --------- ------------------------------ 5.8/24.6 MB 20.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 6.6/24.6 MB 19.3 MB/s eta 0:00:01
#    ------------ --------------------------- 7.6/24.6 MB 20.2 MB/s eta 0:00:01
#    ------------- -------------------------- 8.5/24.6 MB 19.4 MB/s eta 0:00:01
#    --------------- ------------------------ 9.3/24.6 MB 19.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 11.0/24.6 MB 20.5 MB/s eta 0:00:01
#    ------------------- -------------------- 12.0/24.6 MB 20.5 MB/s eta 0:00:01
#    --------------------- ------------------ 13.2/24.6 MB 21.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 14.1/24.6 MB 21.1 MB/s eta 0:00:01
#    ------------------------ --------------- 15.3/24.6 MB 21.1 MB/s eta 0:00:01
#    -------------------------- ------------- 16.4/24.6 MB 21.8 MB/s eta 0:00:01
#    --------------------------- ------------ 16.8/24.6 MB 21.8 MB/s eta 0:00:01
#    --------------------------- ------------ 16.8/24.6 MB 21.8 MB/s eta 0:00:01
#    --------------------------- ------------ 16.8/24.6 MB 21.8 MB/s eta 0:00:01
#    --------------------------- ------------ 16.8/24.6 MB 21.8 MB/s eta 0:00:01
#    --------------------------- ------------ 16.9/24.6 MB 15.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.3/24.6 MB 16.0 MB/s eta 0:00:01
#    ------------------------------- -------- 19.2/24.6 MB 15.6 MB/s eta 0:00:01
#    -------------------------------- ------- 19.7/24.6 MB 15.2 MB/s eta 0:00:01
#    --------------------------------- ------ 20.4/24.6 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.2/24.6 MB 14.9 MB/s eta 0:00:01
#    ------------------------------------ --- 22.2/24.6 MB 14.9 MB/s eta 0:00:01
#    ------------------------------------- -- 23.3/24.6 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  24.3/24.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  24.6/24.6 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 24.6/24.6 MB 13.6 MB/s eta 0:00:00
# Downloading pybcj-1.0.2-cp39-cp39-win_amd64.whl (24 kB)
# Downloading pycryptodomex-3.19.0-cp35-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 17.0 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 18.6 MB/s eta 0:00:00
# Downloading pyppmd-1.1.0-cp39-cp39-win_amd64.whl (46 kB)
#    ---------------------------------------- 0.0/46.1 kB ? eta -:--:--
#    ---------------------------------------- 46.1/46.1 kB 2.2 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ---------------------------------------- 0.0/502.5 kB ? eta -:--:--
#    --------------------------------------- 502.5/502.5 kB 30.8 MB/s eta 0:00:00
# Downloading pyzstd-0.15.9-cp39-cp39-win_amd64.whl (245 kB)
#    ---------------------------------------- 0.0/245.3 kB ? eta -:--:--
#    --------------------------------------- 245.3/245.3 kB 15.7 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 5.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.15-py39-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    ---------------------------------------- 133.3/133.3 kB ? eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading xxhash-3.4.1-cp39-cp39-win_amd64.whl (29 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading frozenlist-1.4.0-cp39-cp39-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.7 kB ? eta -:--:--
#    ---------------------------------------- 44.7/44.7 kB 2.2 MB/s eta 0:00:00
# Downloading yarl-1.9.3-cp39-cp39-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.2 kB ? eta -:--:--
#    ---------------------------------------- 76.2/76.2 kB ? eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py): started
#   Building wheel for rouge-score (setup.py): finished with status 'done'
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24989 sha256=a6ecca3ec9e27a327645dcc93a3f2b23287fc7604a63451cceb083d59fd4ba54
#   Stored in directory: c:\users\zhilin\appdata\local\pip\cache\wheels\9b\3d\39\09558097d3119ca0a4d462df68f22c6f3c1b345ac63a09b86e
# Successfully built rouge-score
# Installing collected packages: texttable, pytz, brotli, xxhash, tzdata, pyzstd, pytesseract, pyppmd, pycryptodomex, pybcj, pyarrow-hotfix, pyarrow, multivolumefile, multidict, inflate64, frozenlist, dill, click, async-timeout, yarl, responses, py7zr, pandas, nltk, multiprocess, aiosignal, rouge-score, aiohttp, datasets, evaluate
# Successfully installed aiohttp-3.9.1 aiosignal-1.3.1 async-timeout-4.0.3 brotli-1.1.0 click-8.1.7 datasets-2.15.0 dill-0.3.7 evaluate-0.4.1 frozenlist-1.4.0 inflate64-1.0.0 multidict-6.0.4 multiprocess-0.70.15 multivolumefile-0.2.3 nltk-3.8.1 pandas-2.1.3 py7zr-0.20.8 pyarrow-14.0.1 pyarrow-hotfix-0.6 pybcj-1.0.2 pycryptodomex-3.19.0 pyppmd-1.1.0 pytesseract-0.3.10 pytz-2023.3.post1 pyzstd-0.15.9 responses-0.18.0 rouge-score-0.1.2 texttable-1.7.0 tzdata-2023.3 xxhash-3.4.1 yarl-1.9.3

# %%
# install git-fls for pushing model and logs to the hugging face hub
# !sudo apt-get install git-lfs --yes
! pip install git-lfs --yes
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: --yes

# %% [markdown]
# This example will use the [Hugging Face Hub](https://huggingface.co/models) as a remote model versioning service. To be able to push our model to the Hub, you need to register on the [Hugging Face](https://huggingface.co/join).
# If you already have an account, you can skip this step.
# After you have an account, we will use the `notebook_login` util from the `huggingface_hub` package to log into our account and store our token (access key) on the disk.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## 2. Load and prepare samsum dataset
#
# we will use the [samsum](https://huggingface.co/datasets/samsum) dataset a collection of about 16k messenger-like conversations with summaries. Conversations were created and written down by linguists fluent in English.
#
# ```json
# {
#   "id": "13818513",
#   "summary": "Amanda baked cookies and will bring Jerry some tomorrow.",
#   "dialogue": "Amanda: I baked cookies. Do you want some?\r\nJerry: Sure!\r\nAmanda: I'll bring you tomorrow :-)"
# }
# ```

# %% [markdown]
# To load the `samsum` dataset, we use the `load_dataset()` method from the 🤗 Datasets library.

# %%
from datasets import load_dataset, Dataset
import pandas as pd

train_df = pd.read_csv('training.csv')
val_df = pd.read_csv('validation.csv')

train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)

# Fine-tune the model using a portion of the training dataset for validation
# train_data_size = int(0.9 * len(dataset))
# train_dataset = dataset.select(list(range(train_data_size)))
# val_dataset = dataset.select(list(range(train_data_size, len(dataset))))

print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(val_dataset)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):

# %% [markdown]
# Lets checkout an example of the dataset.

# %%
from random import randrange

sample = train_dataset[randrange(len(train_dataset))]
print(f"user_input: \n{sample['user_input']}\n---------------")
print(f"prompt: \n{sample['prompt']}\n---------------")

# %% [markdown]
# To train our model we need to convert our inputs (text) to token IDs. This is done by a 🤗 Transformers Tokenizer. If you are not sure what this means check out [chapter 6](https://huggingface.co/course/chapter6/1?fw=tf) of the Hugging Face Course.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_id="google/flan-t5-base"

# Load tokenizer of FLAN-t5-base
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %% [markdown]
# before we can start training we need to preprocess our data. Abstractive Summarization is a text2text-generation task. This means our model will take a text as input and generate a summary as output. For this we want to understand how long our input and output will be to be able to efficiently batch our data.

# %%
from datasets import concatenate_datasets

# The maximum total input sequence length after tokenization.
# Sequences longer than this will be truncated, sequences shorter will be padded.
tokenized_inputs = concatenate_datasets([train_dataset, val_dataset]).map(lambda x: tokenizer(x["user_input"], truncation=True), batched=True, remove_columns=["user_input", "prompt"])
max_source_length = max([len(x) for x in tokenized_inputs["input_ids"]])
print(f"Max source length: {max_source_length}")

# The maximum total sequence length for target text after tokenization.
# Sequences longer than this will be truncated, sequences shorter will be padded."
tokenized_targets = concatenate_datasets([train_dataset, val_dataset]).map(lambda x: tokenizer(x["prompt"], truncation=True), batched=True, remove_columns=["user_input", "prompt"])
max_target_length = max([len(x) for x in tokenized_targets["input_ids"]])
print(f"Max target length: {max_target_length}")
# Out:
# Map:   0%|          | 0/280 [00:00<?, ? examples/s]
# Map:   0%|          | 0/280 [00:00<?, ? examples/s]

# %%
def preprocess_function(sample,padding="max_length"):
    # add prefix to the input for t5
    inputs = [item for item in sample["user_input"]]

    # tokenize inputs
    model_inputs = tokenizer(inputs, max_length=max_source_length, padding=padding, truncation=True)

    # Tokenize targets with the `text_target` keyword argument
    labels = tokenizer(text_target=sample["prompt"], max_length=max_target_length, padding=padding, truncation=True)

    # If we are padding here, replace all tokenizer.pad_token_id in the labels by -100 when we want to ignore
    # padding in the loss.
    if padding == "max_length":
        labels["input_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
        ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_train_dataset = train_dataset.map(preprocess_function, batched=True, remove_columns=["user_input", "prompt"])
tokenized_val_dataset = val_dataset.map(preprocess_function, batched=True, remove_columns=["user_input", "prompt"])
print(f"Keys of tokenized train dataset: {list(tokenized_train_dataset.features)}")
print(f"Keys of tokenized validation dataset: {list(tokenized_val_dataset.features)}")
# Out:
# Map:   0%|          | 0/233 [00:00<?, ? examples/s]
# Map:   0%|          | 0/47 [00:00<?, ? examples/s]

# %% [markdown]
# ## 3. Fine-tune and evaluate FLAN-T5
#
# After we have processed our dataset, we can start training our model. Therefore we first need to load our [FLAN-T5](https://huggingface.co/models?search=flan-t5) from the Hugging Face Hub. In the example we are using a instance with a NVIDIA V100 meaning that we will fine-tune the `base` version of the model.
# _I plan to do a follow-up post on how to fine-tune the `xxl` version of the model using Deepspeed._

# %%
from transformers import AutoModelForSeq2SeqLM

# huggingface hub model id
model_id="google/flan-t5-base"

# load model from the hub
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %% [markdown]
# We want to evaluate our model during training. The `Trainer` supports evaluation during training by providing a `compute_metrics`.
# The most commonly used metrics to evaluate summarization task is [rogue_score](https://en.wikipedia.org/wiki/ROUGE_(metric)) short for Recall-Oriented Understudy for Gisting Evaluation). This metric does not behave like the standard accuracy: it will compare a generated summary against a set of reference summaries
#
# We are going to use `evaluate` library to evaluate the `rogue` score.

# %%
import evaluate
import nltk
import numpy as np
from nltk.tokenize import sent_tokenize
nltk.download("punkt")

# Metric
metric = evaluate.load("rouge")

# helper function to postprocess text
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]

    # rougeLSum expects newline after each sentence
    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]

    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    result = {k: round(v * 100, 4) for k, v in result.items()}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    return result
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %% [markdown]
# Before we can start training is to create a `DataCollator` that will take care of padding our inputs and labels. We will use the `DataCollatorForSeq2Seq` from the 🤗 Transformers library.

# %%
from transformers import DataCollatorForSeq2Seq

# we want to ignore tokenizer pad token in the loss
label_pad_token_id = -100
# Data collator
data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    label_pad_token_id=label_pad_token_id,
    pad_to_multiple_of=8
)

# %% [markdown]
# The last step is to define the hyperparameters (`TrainingArguments`) we want to use for our training. We are leveraging the [Hugging Face Hub](https://huggingface.co/models) integration of the `Trainer` to automatically push our checkpoints, logs and metrics during training into a repository.

# %%
# ! pip install -U accelerate
# ! pip install -U transformers

# %%
from huggingface_hub import HfFolder
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments
import accelerate
import transformers

print(transformers.__version__, accelerate.__version__)

# Hugging Face repository id
repository_id = "flan-t5-sentence-generator"

# Define training args
training_args = Seq2SeqTrainingArguments(
    output_dir=repository_id,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    fp16=False, # Overflows with fp16
    learning_rate=5e-5,
    num_train_epochs=10,
    # logging & evaluation strategies
    logging_dir=f"{repository_id}/logs",
    logging_strategy="steps",
    logging_steps=500,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    # metric_for_best_model="overall_f1",
    # push to hub parameters
    report_to="tensorboard",
    push_to_hub=False,
    hub_strategy="every_save",
    hub_model_id=repository_id,
    hub_token=HfFolder.get_token(),
)

# Create Trainer instance
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics,
)

# %% [markdown]
# We can start our training by using the `train` method of the `Trainer`.

# %%
# Start training
trainer.train()
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 04:33, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.394709</td>
#       <td>88.645800</td>
#       <td>75.403100</td>
#       <td>88.167500</td>
#       <td>88.271800</td>
#       <td>11.085106</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.260757</td>
#       <td>92.279200</td>
#       <td>81.347000</td>
#       <td>92.356100</td>
#       <td>92.395100</td>
#       <td>11.723404</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.224208</td>
#       <td>93.091700</td>
#       <td>83.478700</td>
#       <td>93.164300</td>
#       <td>93.191600</td>
#       <td>11.765957</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.205561</td>
#       <td>93.753100</td>
#       <td>86.045000</td>
#       <td>93.821800</td>
#       <td>93.851400</td>
#       <td>11.829787</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.199493</td>
#       <td>93.739600</td>
#       <td>85.706400</td>
#       <td>93.750800</td>
#       <td>93.861000</td>
#       <td>11.787234</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.202067</td>
#       <td>93.596500</td>
#       <td>85.292100</td>
#       <td>93.681900</td>
#       <td>93.709600</td>
#       <td>11.829787</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.208932</td>
#       <td>93.596500</td>
#       <td>85.292100</td>
#       <td>93.681900</td>
#       <td>93.709600</td>
#       <td>11.829787</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>0.207259</td>
#       <td>93.828900</td>
#       <td>85.783200</td>
#       <td>93.862300</td>
#       <td>93.947500</td>
#       <td>11.829787</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>0.208346</td>
#       <td>93.828900</td>
#       <td>85.783200</td>
#       <td>93.862300</td>
#       <td>93.947500</td>
#       <td>11.829787</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>0.208696</td>
#       <td>93.828900</td>
#       <td>85.783200</td>
#       <td>93.862300</td>
#       <td>93.947500</td>
#       <td>11.829787</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight'].
# TrainOutput(global_step=300, training_loss=0.46145736694335937, metrics={'train_runtime': 276.4923, 'train_samples_per_second': 8.427, 'train_steps_per_second': 1.085, 'total_flos': 99717789450240.0, 'train_loss': 0.46145736694335937, 'epoch': 10.0})

# %% [markdown]
# Nice, we have trained our model. 🎉 Lets run evaluate the best model again on the test set.

# %%
trainer.evaluate()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:01]
#     </div>
# {'eval_loss': 0.1994926929473877,
#  'eval_rouge1': 93.7396,
#  'eval_rouge2': 85.7064,
#  'eval_rougeL': 93.7508,
#  'eval_rougeLsum': 93.861,
#  'eval_gen_len': 11.787234042553191,
#  'eval_runtime': 2.388,
#  'eval_samples_per_second': 19.682,
#  'eval_steps_per_second': 2.513,
#  'epoch': 10.0}

# %% [markdown]
# The best score we achieved is an `rouge1` score of `47.23`.
#
# Lets save our results and tokenizer to the Hugging Face Hub and create a model card.

# %%
# Save our tokenizer and create model card
tokenizer.save_pretrained(repository_id)
trainer.create_model_card()
# Push the results to the hub
trainer.push_to_hub()
# Out:
# events.out.tfevents.1700834475.45f586c7d5ae.949.0:   0%|          | 0.00/10.8k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# events.out.tfevents.1700834754.45f586c7d5ae.949.1:   0%|          | 0.00/613 [00:00<?, ?B/s]
# training_args.bin:   0%|          | 0.00/4.73k [00:00<?, ?B/s]
# 'https://huggingface.co/EngLip/flan-t5-base-fineTuned/tree/main/'

# %% [markdown]
# ## 4. Run Inference
#
# Now we have a trained model, we can use it to run inference. We will use the `pipeline` API from transformers and a `test` example from our dataset.

# %%
from transformers import pipeline
from random import randrange

# load model and tokenizer from huggingface hub with pipeline
keyToText = pipeline("text2text-generation", model="EngLip/flan-t5-sentence-generator")
# keyToText = pipeline("text2text-generation", model="./flan-t5-base-fineTuned", device=0)

# # select a random test sample
# sample = val_dataset[randrange(len(val_dataset))]
# print(f"userInput: \n{sample['user_input']}\n---------------")

# # summarize dialogue
# res = keyToText(sample["user_input"])

# print(f"flan-t5-base summary:\n{res[0]}")
# Out:
# config.json:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/20.8k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
# res = keyToText("me not want sleep night")

# select a random test sample
# sample = val_dataset[randrange(len(val_dataset))]
# print(f"userInput: \n{sample['user_input']}\n---------------")

# res = keyToText(sample["user_input"])
res = keyToText("he/she, same/also, like, cookie")

print(f"flan-t5-base:\n{res}\n")
# print(f"actual:\n{sample['prompt']}")
# Out:
# flan-t5-base:
# [{'generated_text': 'She also likes a cookie.'}]
